# %% [markdown]
# # How to use the TranslationDataloader class
# TranslationDataloader helps to provide datasets for translator with a variety of options. This ipynb file provides a simple example of using TranslationDataloader.

# %% [markdown]
# You need the fire module to run the example. This module makes python objects executable with CLI.

# %%
pip install fire

# %% [markdown]
# Set the execution path of the ipython file to the project_NLG folder. The PATH should be changed appropriately according to the user's environment.

# %%
PATH = '/content/drive/MyDrive/Colab Notebooks/project_NLG'
# %cd $PATH

# %% [markdown]
# If you want to know about the options to run the example, you can run the following command.

# %%
# !python ./data_loader/data_loader.py test -- --help

# %% [markdown]
# Run the example as follows.

# %%
# !python ./data_loader/data_loader.py test ./dataset/corpus_shuf_train_tok_bpe ./dataset/corpus_shuf_valid_tok_bpe '(en, ko)' --max_length 1000 --num_parallel_reads 2 --num_workers 2 --lazy True
